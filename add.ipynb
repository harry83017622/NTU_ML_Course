# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

myseed = 42069  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %%
from tensorboardX import SummaryWriter 
#SummaryWriter 是一個類別，包含這套件的所有功能。

writer = SummaryWriter(comment='test')
#在預設資料夾後面加上註解 檔名變為：'runs/Aug20-obov01-3xLR'

# %%
if torch.cuda.is_available():
  print("is available")
# Out:
# is available

# %%
class Model(nn.Module):
  def __init__(self, n):
    super(Model,self).__init__()
    self.linear = nn.Linear(n,1,bias=False)
    self.criterion = nn.MSELoss(reduction='mean')
  def forward(self, x):
    output = self.linear(x).squeeze(1)
    return output

  def cal_loss(self, pred, target):
    ''' Calculate loss '''
    # TODO: you may implement L1/L2 regularization here
    
    return self.criterion(pred, target)

# %%
def train(tr_set, dv_set, model, config, device):
    ''' DNN training '''

    n_epochs = config['n_epochs']  # Maximum number of epochs

    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    iter_idx = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())
            writer.add_scalar('myscalar', mse_loss.detach().cpu().item(), iter_idx)
            iter_idx+=1
        # After each epoch, test your model on the validation (development) set.
        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            # Stop training if your model stops improving for "config['early_stop']" epochs.
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
        
    
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
target_only = True                    # TODO: Using 40 states & 2 tested_positive features

# TODO: How to tune these hyper-parameters to improve your model's performance?
config = {
    'n_epochs': 3000,                # maximum number of epochs
    'batch_size': 150,               # mini-batch size for dataloader
    'optimizer': 'Adam',              # optimization algorithm (optimizer in torch.optim)
    'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
        # 'lr': 0.001,                 # learning rate of SGD
        # 'momentum': 0.9              # momentum for SGD
    },
    'early_stop': 200,               # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %%
model = Model(4).to(device)  # Construct model and move to device

# %%
class RandomDataset(Dataset):
    ''' Dataset for loading and preprocessing the COVID19 dataset '''
    def __init__(self,
                 data,
                 mode='train',
                 target_only=False):
        self.mode = mode

        target = data[1]
        data = data[0]
        
        # Splitting training data into train & dev sets
        if mode == 'train':
            indices = [i for i in range(len(data)) if i % 10 != 0]
        elif mode == 'dev':
            indices = [i for i in range(len(data)) if i % 10 == 0]
        
        # Convert data into PyTorch tensors
        self.data = data[indices].type(torch.FloatTensor)
        # self.data = torch.FloatTensor(data[indices])
        self.target = target[indices].type(torch.FloatTensor)
        # self.target = torch.FloatTensor(target[indices])
        
        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing (no target)
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %%
# dataset = RandomDataset((tr_x,tr_y), 'train', target_only=False)
# a,b=dataset[0]
# print(a,b)

# %%
def prep_dataloader(data, mode, batch_size, n_jobs=0, target_only=False):
    ''' Generates a dataset, then is put into a dataloader. '''
    dataset = RandomDataset(data, mode=mode, target_only=target_only)  # Construct dataset
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)                            # Construct dataloader
    return dataloader

# %%
tr_x = torch.randint(100,(3000,4))
tr_y = torch.sum(tr_x, 1)




tr_set = prep_dataloader((tr_x,tr_y), 'train', config['batch_size'], target_only=target_only)
dv_set = prep_dataloader((tr_x,tr_y), 'dev', config['batch_size'], target_only=target_only)
# Out:
# Finished reading the train set of COVID19 Dataset (2700 samples found, each dim = 4)
# Finished reading the dev set of COVID19 Dataset (300 samples found, each dim = 4)

# %%
# for x in tr_set:
#   print(x[0])

# %%
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =   65, loss = 989.4671)
# Saving model (epoch =   66, loss = 918.6872)
# Saving model (epoch =   67, loss = 852.5357)
# Saving model (epoch =   68, loss = 790.8852)
# Saving model (epoch =   69, loss = 733.7697)
# Saving model (epoch =   70, loss = 680.1009)
# Saving model (epoch =   71, loss = 630.3573)
# Saving model (epoch =   72, loss = 584.0602)
# Saving model (epoch =   73, loss = 541.5363)
# Saving model (epoch =   74, loss = 501.4531)
# Saving model (epoch =   75, loss = 464.9681)
# Saving model (epoch =   76, loss = 430.7299)
# Saving model (epoch =   77, loss = 399.3001)
# Saving model (epoch =   78, loss = 370.0915)
# Saving model (epoch =   79, loss = 343.4648)
# Saving model (epoch =   80, loss = 318.7116)
# Saving model (epoch =   81, loss = 295.9326)
# Saving model (epoch =   82, loss = 275.0251)
# Saving model (epoch =   83, loss = 255.6567)
# Saving model (epoch =   84, loss = 237.9556)
# Saving model (epoch =   85, loss = 221.7939)
# Saving model (epoch =   86, loss = 206.8433)
# Saving model (epoch =   87, loss = 193.2900)
# Saving model (epoch =   88, loss = 180.8053)
# Saving model (epoch =   89, loss = 169.4481)
# Saving model (epoch =   90, loss = 158.8324)
# Saving model (epoch =   91, loss = 149.3372)
# Saving model (epoch =   92, loss = 140.5707)
# Saving model (epoch =   93, loss = 132.6550)
# Saving model (epoch =   94, loss = 125.3909)
# Saving model (epoch =   95, loss = 118.8435)
# Saving model (epoch =   96, loss = 112.7854)
# Saving model (epoch =   97, loss = 107.3553)
# Saving model (epoch =   98, loss = 102.3358)
# Saving model (epoch =   99, loss = 97.7563)
# Saving model (epoch =  100, loss = 93.5791)
# Saving model (epoch =  101, loss = 89.7643)
# Saving model (epoch =  102, loss = 86.2933)
# Saving model (epoch =  103, loss = 83.1696)
# Saving model (epoch =  104, loss = 80.2623)
# Saving model (epoch =  105, loss = 77.6322)
# Saving model (epoch =  106, loss = 75.1923)
# Saving model (epoch =  107, loss = 72.9882)
# Saving model (epoch =  108, loss = 70.9355)
# Saving model (epoch =  109, loss = 69.0500)
# Saving model (epoch =  110, loss = 67.3073)
# Saving model (epoch =  111, loss = 65.7012)
# Saving model (epoch =  112, loss = 64.1803)
# Saving model (epoch =  113, loss = 62.8112)
# Saving model (epoch =  114, loss = 61.5140)
# Saving model (epoch =  115, loss = 60.2992)
# Saving model (epoch =  116, loss = 59.1677)
# Saving model (epoch =  117, loss = 58.0915)
# Saving model (epoch =  118, loss = 57.0693)
# Saving model (epoch =  119, loss = 56.1011)
# Saving model (epoch =  120, loss = 55.1887)
# Saving model (epoch =  121, loss = 54.2945)
# Saving model (epoch =  122, loss = 53.4537)
# Saving model (epoch =  123, loss = 52.6297)
# Saving model (epoch =  124, loss = 51.8474)
# Saving model (epoch =  125, loss = 51.0824)
# Saving model (epoch =  126, loss = 50.3547)
# Saving model (epoch =  127, loss = 49.6355)
# Saving model (epoch =  128, loss = 48.9208)
# Saving model (epoch =  129, loss = 48.2363)
# Saving model (epoch =  130, loss = 47.5621)
# Saving model (epoch =  131, loss = 46.9001)
# Saving model (epoch =  132, loss = 46.2448)
# Saving model (epoch =  133, loss = 45.6029)
# Saving model (epoch =  134, loss = 44.9686)
# Saving model (epoch =  135, loss = 44.3439)
# Saving model (epoch =  136, loss = 43.7148)
# Saving model (epoch =  137, loss = 43.1068)
# Saving model (epoch =  138, loss = 42.4980)
# Saving model (epoch =  139, loss = 41.8985)
# Saving model (epoch =  140, loss = 41.2964)
# Saving model (epoch =  141, loss = 40.7055)
# Saving model (epoch =  142, loss = 40.1171)
# Saving model (epoch =  143, loss = 39.5397)
# Saving model (epoch =  144, loss = 38.9553)
# Saving model (epoch =  145, loss = 38.3814)
# Saving model (epoch =  146, loss = 37.8120)
# Saving model (epoch =  147, loss = 37.2497)
# Saving model (epoch =  148, loss = 36.6812)
# Saving model (epoch =  149, loss = 36.1253)
# Saving model (epoch =  150, loss = 35.5597)
# Saving model (epoch =  151, loss = 35.0152)
# Saving model (epoch =  152, loss = 34.4644)
# Saving model (epoch =  153, loss = 33.9224)
# Saving model (epoch =  154, loss = 33.3782)
# Saving model (epoch =  155, loss = 32.8362)
# Saving model (epoch =  156, loss = 32.3007)
# Saving model (epoch =  157, loss = 31.7692)
# Saving model (epoch =  158, loss = 31.2488)
# Saving model (epoch =  159, loss = 30.7219)
# Saving model (epoch =  160, loss = 30.2021)
# Saving model (epoch =  161, loss = 29.6943)
# Saving model (epoch =  162, loss = 29.1802)
# Saving model (epoch =  163, loss = 28.6704)
# Saving model (epoch =  164, loss = 28.1712)
# Saving model (epoch =  165, loss = 27.6694)
# Saving model (epoch =  166, loss = 27.1812)
# Saving model (epoch =  167, loss = 26.6947)
# Saving model (epoch =  168, loss = 26.2072)
# Saving model (epoch =  169, loss = 25.7266)
# Saving model (epoch =  170, loss = 25.2439)
# Saving model (epoch =  171, loss = 24.7760)
# Saving model (epoch =  172, loss = 24.3010)
# Saving model (epoch =  173, loss = 23.8361)
# Saving model (epoch =  174, loss = 23.3827)
# Saving model (epoch =  175, loss = 22.9280)
# Saving model (epoch =  176, loss = 22.4764)
# Saving model (epoch =  177, loss = 22.0361)
# Saving model (epoch =  178, loss = 21.5947)
# Saving model (epoch =  179, loss = 21.1623)
# Saving model (epoch =  180, loss = 20.7330)
# Saving model (epoch =  181, loss = 20.3029)
# Saving model (epoch =  182, loss = 19.8803)
# Saving model (epoch =  183, loss = 19.4658)
# Saving model (epoch =  184, loss = 19.0556)
# Saving model (epoch =  185, loss = 18.6510)
# Saving model (epoch =  186, loss = 18.2489)
# Saving model (epoch =  187, loss = 17.8548)
# Saving model (epoch =  188, loss = 17.4637)
# Saving model (epoch =  189, loss = 17.0769)
# Saving model (epoch =  190, loss = 16.6959)
# Saving model (epoch =  191, loss = 16.3173)
# Saving model (epoch =  192, loss = 15.9488)
# Saving model (epoch =  193, loss = 15.5812)
# Saving model (epoch =  194, loss = 15.2213)
# Saving model (epoch =  195, loss = 14.8667)
# Saving model (epoch =  196, loss = 14.5165)
# Saving model (epoch =  197, loss = 14.1679)
# Saving model (epoch =  198, loss = 13.8288)
# Saving model (epoch =  199, loss = 13.4951)
# Saving model (epoch =  200, loss = 13.1633)
# Saving model (epoch =  201, loss = 12.8352)
# Saving model (epoch =  202, loss = 12.5159)
# Saving model (epoch =  203, loss = 12.2011)
# Saving model (epoch =  204, loss = 11.8928)
# Saving model (epoch =  205, loss = 11.5868)
# Saving model (epoch =  206, loss = 11.2904)
# Saving model (epoch =  207, loss = 10.9972)
# Saving model (epoch =  208, loss = 10.7039)
# Saving model (epoch =  209, loss = 10.4206)
# Saving model (epoch =  210, loss = 10.1411)
# Saving model (epoch =  211, loss = 9.8695)
# Saving model (epoch =  212, loss = 9.5994)
# Saving model (epoch =  213, loss = 9.3316)
# Saving model (epoch =  214, loss = 9.0751)
# Saving model (epoch =  215, loss = 8.8206)
# Saving model (epoch =  216, loss = 8.5674)
# Saving model (epoch =  217, loss = 8.3238)
# Saving model (epoch =  218, loss = 8.0853)
# Saving model (epoch =  219, loss = 7.8488)
# Saving model (epoch =  220, loss = 7.6202)
# Saving model (epoch =  221, loss = 7.3946)
# Saving model (epoch =  222, loss = 7.1730)
# Saving model (epoch =  223, loss = 6.9541)
# Saving model (epoch =  224, loss = 6.7444)
# Saving model (epoch =  225, loss = 6.5377)
# Saving model (epoch =  226, loss = 6.3341)
# Saving model (epoch =  227, loss = 6.1355)
# Saving model (epoch =  228, loss = 5.9421)
# Saving model (epoch =  229, loss = 5.7515)
# Saving model (epoch =  230, loss = 5.5694)
# Saving model (epoch =  231, loss = 5.3887)
# Saving model (epoch =  232, loss = 5.2102)
# Saving model (epoch =  233, loss = 5.0394)
# Saving model (epoch =  234, loss = 4.8710)
# Saving model (epoch =  235, loss = 4.7082)
# Saving model (epoch =  236, loss = 4.5463)
# Saving model (epoch =  237, loss = 4.3907)
# Saving model (epoch =  238, loss = 4.2398)
# Saving model (epoch =  239, loss = 4.0913)
# Saving model (epoch =  240, loss = 3.9465)
# Saving model (epoch =  241, loss = 3.8081)
# Saving model (epoch =  242, loss = 3.6702)
# Saving model (epoch =  243, loss = 3.5380)
# Saving model (epoch =  244, loss = 3.4099)
# Saving model (epoch =  245, loss = 3.2832)
# Saving model (epoch =  246, loss = 3.1609)
# Saving model (epoch =  247, loss = 3.0431)
# Saving model (epoch =  248, loss = 2.9268)
# Saving model (epoch =  249, loss = 2.8162)
# Saving model (epoch =  250, loss = 2.7074)
# Saving model (epoch =  251, loss = 2.6020)
# Saving model (epoch =  252, loss = 2.5006)
# Saving model (epoch =  253, loss = 2.4017)
# Saving model (epoch =  254, loss = 2.3063)
# Saving model (epoch =  255, loss = 2.2124)
# Saving model (epoch =  256, loss = 2.1226)
# Saving model (epoch =  257, loss = 2.0355)
# Saving model (epoch =  258, loss = 1.9516)
# Saving model (epoch =  259, loss = 1.8696)
# Saving model (epoch =  260, loss = 1.7907)
# Saving model (epoch =  261, loss = 1.7152)
# Saving model (epoch =  262, loss = 1.6413)
# Saving model (epoch =  263, loss = 1.5702)
# Saving model (epoch =  264, loss = 1.5012)
# Saving model (epoch =  265, loss = 1.4353)
# Saving model (epoch =  266, loss = 1.3711)
# Saving model (epoch =  267, loss = 1.3102)
# Saving model (epoch =  268, loss = 1.2512)
# Saving model (epoch =  269, loss = 1.1942)
# Saving model (epoch =  270, loss = 1.1391)
# Saving model (epoch =  271, loss = 1.0856)
# Saving model (epoch =  272, loss = 1.0347)
# Saving model (epoch =  273, loss = 0.9857)
# Saving model (epoch =  274, loss = 0.9391)
# Saving model (epoch =  275, loss = 0.8930)
# Saving model (epoch =  276, loss = 0.8497)
# Saving model (epoch =  277, loss = 0.8083)
# Saving model (epoch =  278, loss = 0.7684)
# Saving model (epoch =  279, loss = 0.7300)
# Saving model (epoch =  280, loss = 0.6933)
# Saving model (epoch =  281, loss = 0.6576)
# Saving model (epoch =  282, loss = 0.6237)
# Saving model (epoch =  283, loss = 0.5916)
# Saving model (epoch =  284, loss = 0.5610)
# Saving model (epoch =  285, loss = 0.5311)
# Saving model (epoch =  286, loss = 0.5033)
# Saving model (epoch =  287, loss = 0.4764)
# Saving model (epoch =  288, loss = 0.4500)
# Saving model (epoch =  289, loss = 0.4257)
# Saving model (epoch =  290, loss = 0.4021)
# Saving model (epoch =  291, loss = 0.3798)
# Saving model (epoch =  292, loss = 0.3586)
# Saving model (epoch =  293, loss = 0.3382)
# Saving model (epoch =  294, loss = 0.3189)
# Saving model (epoch =  295, loss = 0.3004)
# Saving model (epoch =  296, loss = 0.2830)
# Saving model (epoch =  297, loss = 0.2663)
# Saving model (epoch =  298, loss = 0.2505)
# Saving model (epoch =  299, loss = 0.2355)
# Saving model (epoch =  300, loss = 0.2214)
# Saving model (epoch =  301, loss = 0.2081)
# Saving model (epoch =  302, loss = 0.1953)
# Saving model (epoch =  303, loss = 0.1831)
# Saving model (epoch =  304, loss = 0.1718)
# Saving model (epoch =  305, loss = 0.1609)
# Saving model (epoch =  306, loss = 0.1507)
# Saving model (epoch =  307, loss = 0.1410)
# Saving model (epoch =  308, loss = 0.1318)
# Saving model (epoch =  309, loss = 0.1233)
# Saving model (epoch =  310, loss = 0.1151)
# Saving model (epoch =  311, loss = 0.1075)
# Saving model (epoch =  312, loss = 0.1003)
# Saving model (epoch =  313, loss = 0.0936)
# Saving model (epoch =  314, loss = 0.0871)
# Saving model (epoch =  315, loss = 0.0812)
# Saving model (epoch =  316, loss = 0.0755)
# Saving model (epoch =  317, loss = 0.0702)
# Saving model (epoch =  318, loss = 0.0653)
# Saving model (epoch =  319, loss = 0.0606)
# Saving model (epoch =  320, loss = 0.0562)
# Saving model (epoch =  321, loss = 0.0522)
# Saving model (epoch =  322, loss = 0.0483)
# Saving model (epoch =  323, loss = 0.0448)
# Saving model (epoch =  324, loss = 0.0414)
# Saving model (epoch =  325, loss = 0.0383)
# Saving model (epoch =  326, loss = 0.0354)
# Saving model (epoch =  327, loss = 0.0327)
# Saving model (epoch =  328, loss = 0.0302)
# Saving model (epoch =  329, loss = 0.0278)
# Saving model (epoch =  330, loss = 0.0256)
# Saving model (epoch =  331, loss = 0.0236)
# Saving model (epoch =  332, loss = 0.0217)
# Saving model (epoch =  333, loss = 0.0199)
# Saving model (epoch =  334, loss = 0.0183)
# Saving model (epoch =  335, loss = 0.0168)
# Saving model (epoch =  336, loss = 0.0154)
# Saving model (epoch =  337, loss = 0.0141)
# Saving model (epoch =  338, loss = 0.0129)
# Saving model (epoch =  339, loss = 0.0118)
# Saving model (epoch =  340, loss = 0.0108)
# Saving model (epoch =  341, loss = 0.0099)
# Saving model (epoch =  342, loss = 0.0090)
# Saving model (epoch =  343, loss = 0.0082)
# Saving model (epoch =  344, loss = 0.0075)
# Saving model (epoch =  345, loss = 0.0068)
# Saving model (epoch =  346, loss = 0.0062)
# Saving model (epoch =  347, loss = 0.0056)
# Saving model (epoch =  348, loss = 0.0051)
# Saving model (epoch =  349, loss = 0.0046)
# Saving model (epoch =  350, loss = 0.0042)
# Saving model (epoch =  351, loss = 0.0038)
# Saving model (epoch =  352, loss = 0.0034)
# Saving model (epoch =  353, loss = 0.0031)
# Saving model (epoch =  354, loss = 0.0028)
# Saving model (epoch =  355, loss = 0.0025)
# Saving model (epoch =  356, loss = 0.0023)
# Saving model (epoch =  357, loss = 0.0021)
# Saving model (epoch =  358, loss = 0.0018)
# Saving model (epoch =  359, loss = 0.0017)
# Saving model (epoch =  360, loss = 0.0015)
# Saving model (epoch =  361, loss = 0.0013)
# Saving model (epoch =  362, loss = 0.0012)
# Saving model (epoch =  363, loss = 0.0011)
# Saving model (epoch =  364, loss = 0.0010)
# Saving model (epoch =  365, loss = 0.0009)
# Saving model (epoch =  366, loss = 0.0008)
# Saving model (epoch =  367, loss = 0.0007)
# Saving model (epoch =  368, loss = 0.0006)
# Saving model (epoch =  369, loss = 0.0005)
# Saving model (epoch =  370, loss = 0.0005)
# Saving model (epoch =  371, loss = 0.0004)
# Saving model (epoch =  372, loss = 0.0004)
# Saving model (epoch =  373, loss = 0.0003)
# Saving model (epoch =  374, loss = 0.0003)
# Saving model (epoch =  375, loss = 0.0003)
# Saving model (epoch =  376, loss = 0.0002)
# Saving model (epoch =  377, loss = 0.0002)
# Saving model (epoch =  378, loss = 0.0002)
# Saving model (epoch =  379, loss = 0.0002)
# Saving model (epoch =  380, loss = 0.0001)
# Saving model (epoch =  381, loss = 0.0001)
# Saving model (epoch =  382, loss = 0.0001)
# Saving model (epoch =  383, loss = 0.0001)
# Saving model (epoch =  384, loss = 0.0001)
# Saving model (epoch =  385, loss = 0.0001)
# Saving model (epoch =  386, loss = 0.0001)
# Saving model (epoch =  387, loss = 0.0001)
# Saving model (epoch =  388, loss = 0.0000)
# Saving model (epoch =  389, loss = 0.0000)
# Saving model (epoch =  390, loss = 0.0000)
# Saving model (epoch =  391, loss = 0.0000)
# Saving model (epoch =  392, loss = 0.0000)
# Saving model (epoch =  393, loss = 0.0000)
# Saving model (epoch =  394, loss = 0.0000)
# Saving model (epoch =  395, loss = 0.0000)
# Saving model (epoch =  396, loss = 0.0000)
# Saving model (epoch =  397, loss = 0.0000)
# Saving model (epoch =  398, loss = 0.0000)
# Saving model (epoch =  399, loss = 0.0000)
# Saving model (epoch =  400, loss = 0.0000)
# Saving model (epoch =  401, loss = 0.0000)
# Saving model (epoch =  402, loss = 0.0000)
# Saving model (epoch =  403, loss = 0.0000)
# Saving model (epoch =  404, loss = 0.0000)
# Saving model (epoch =  405, loss = 0.0000)
# Saving model (epoch =  406, loss = 0.0000)
# Saving model (epoch =  407, loss = 0.0000)
# Saving model (epoch =  408, loss = 0.0000)
# Saving model (epoch =  409, loss = 0.0000)
# Saving model (epoch =  410, loss = 0.0000)
# Saving model (epoch =  411, loss = 0.0000)
# Saving model (epoch =  412, loss = 0.0000)
# Saving model (epoch =  413, loss = 0.0000)
# Saving model (epoch =  414, loss = 0.0000)
# Saving model (epoch =  415, loss = 0.0000)
# Saving model (epoch =  416, loss = 0.0000)
# Saving model (epoch =  417, loss = 0.0000)
# Saving model (epoch =  418, loss = 0.0000)
# Saving model (epoch =  419, loss = 0.0000)
# Saving model (epoch =  420, loss = 0.0000)
# Saving model (epoch =  421, loss = 0.0000)
# Saving model (epoch =  422, loss = 0.0000)
# Saving model (epoch =  423, loss = 0.0000)
# Saving model (epoch =  424, loss = 0.0000)
# Saving model (epoch =  425, loss = 0.0000)
# Saving model (epoch =  426, loss = 0.0000)
# Saving model (epoch =  427, loss = 0.0000)
# Saving model (epoch =  429, loss = 0.0000)
# Saving model (epoch =  430, loss = 0.0000)
# Saving model (epoch =  431, loss = 0.0000)
# Saving model (epoch =  432, loss = 0.0000)
# Saving model (epoch =  434, loss = 0.0000)
# Saving model (epoch =  436, loss = 0.0000)
# Saving model (epoch =  441, loss = 0.0000)
# Saving model (epoch =  442, loss = 0.0000)
# Saving model (epoch =  443, loss = 0.0000)
# Saving model (epoch =  444, loss = 0.0000)
# Saving model (epoch =  450, loss = 0.0000)
# Saving model (epoch =  451, loss = 0.0000)
# Saving model (epoch =  458, loss = 0.0000)
# Saving model (epoch =  459, loss = 0.0000)
# Saving model (epoch =  460, loss = 0.0000)
# Saving model (epoch =  461, loss = 0.0000)
# Saving model (epoch =  462, loss = 0.0000)
# Saving model (epoch =  467, loss = 0.0000)
# Saving model (epoch =  471, loss = 0.0000)
# Saving model (epoch =  472, loss = 0.0000)
# Saving model (epoch =  473, loss = 0.0000)
# Saving model (epoch =  479, loss = 0.0000)
# Saving model (epoch =  480, loss = 0.0000)
# Saving model (epoch =  482, loss = 0.0000)
# Saving model (epoch =  483, loss = 0.0000)
# Saving model (epoch =  485, loss = 0.0000)
# Saving model (epoch =  486, loss = 0.0000)
# Saving model (epoch =  488, loss = 0.0000)
# Saving model (epoch =  493, loss = 0.0000)
# Saving model (epoch =  495, loss = 0.0000)
# Saving model (epoch =  496, loss = 0.0000)
# Saving model (epoch =  502, loss = 0.0000)
# Saving model (epoch =  511, loss = 0.0000)
# Saving model (epoch =  512, loss = 0.0000)
# Saving model (epoch =  513, loss = 0.0000)
# Saving model (epoch =  514, loss = 0.0000)
# Saving model (epoch =  515, loss = 0.0000)
# Saving model (epoch =  517, loss = 0.0000)
# Saving model (epoch =  526, loss = 0.0000)
# Saving model (epoch =  528, loss = 0.0000)
# Saving model (epoch =  537, loss = 0.0000)
# Saving model (epoch =  538, loss = 0.0000)
# Saving model (epoch =  539, loss = 0.0000)
# Saving model (epoch =  541, loss = 0.0000)
# Saving model (epoch =  542, loss = 0.0000)
# Saving model (epoch =  543, loss = 0.0000)
# Saving model (epoch =  544, loss = 0.0000)
# Saving model (epoch =  563, loss = 0.0000)
# Saving model (epoch =  564, loss = 0.0000)
# Saving model (epoch =  575, loss = 0.0000)
# Saving model (epoch =  577, loss = 0.0000)
# Saving model (epoch =  578, loss = 0.0000)
# Saving model (epoch =  579, loss = 0.0000)
# Saving model (epoch =  590, loss = 0.0000)
# Saving model (epoch =  592, loss = 0.0000)
# Saving model (epoch =  593, loss = 0.0000)
# Saving model (epoch =  594, loss = 0.0000)
# Saving model (epoch =  596, loss = 0.0000)
# Saving model (epoch =  613, loss = 0.0000)
# Saving model (epoch =  614, loss = 0.0000)
# Saving model (epoch =  615, loss = 0.0000)
# Saving model (epoch =  627, loss = 0.0000)
# Saving model (epoch =  637, loss = 0.0000)
# Saving model (epoch =  638, loss = 0.0000)
# Saving model (epoch =  645, loss = 0.0000)
# Saving model (epoch =  650, loss = 0.0000)
# Saving model (epoch =  654, loss = 0.0000)
# Saving model (epoch =  656, loss = 0.0000)
# Saving model (epoch =  676, loss = 0.0000)
# Saving model (epoch =  677, loss = 0.0000)
# Saving model (epoch =  687, loss = 0.0000)
# Saving model (epoch =  688, loss = 0.0000)
# Saving model (epoch =  689, loss = 0.0000)
# Saving model (epoch =  690, loss = 0.0000)
# Saving model (epoch =  692, loss = 0.0000)
# Saving model (epoch =  694, loss = 0.0000)
# Saving model (epoch =  706, loss = 0.0000)
# Saving model (epoch =  714, loss = 0.0000)
# Saving model (epoch =  715, loss = 0.0000)
# Saving model (epoch =  724, loss = 0.0000)
# Saving model (epoch =  751, loss = 0.0000)
# Saving model (epoch =  752, loss = 0.0000)
# Saving model (epoch =  780, loss = 0.0000)
# Saving model (epoch =  781, loss = 0.0000)
# Saving model (epoch =  816, loss = 0.0000)
# Saving model (epoch =  883, loss = 0.0000)
# Saving model (epoch = 1022, loss = 0.0000)
# Finished training after 1223 epochs

# %%
for param in model.parameters():
  print(param.data)
# Out:
# tensor([[1., 1., 1., 1.]], device='cuda:0')

# %%
m = Model(4)
m.load_state_dict(torch.load('models/model.pth'))
for param in m.parameters():
  print(param.data)
# Out:
# tensor([[1., 1., 1., 1.]])
